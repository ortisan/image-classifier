# %%
# TensorFlow e tf.keras
import tensorflow as tf
from tensorflow import keras

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical 

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
# Out:
# 2.4.1

# %%
import json

# %% [markdown]
# ### Reading the dataset previously classified by hand (Labelled)

# %%
classifier_data = None
with open(f'../classifier/static/classify_data/data.json', 'r') as f:
    classifier_data = json.load(f)
data = classifier_data['data']

# %%
for item in data:
    features = item['features']
    features['id'] = item['id']
    features['label'] = item['label']
    features['name'] = item['name']

features_data = [item['features'] for item in data if len(item['label']) > 0]

# %%
df = pd.DataFrame(features_data)
df.head()
# Out:
#     high    low  close   open                                    id  \
# 0  36.52  35.53  36.52  35.80  5045d02c-7578-11eb-abae-90324bbf5cee
# 1  36.73  35.97  36.14  36.02  5046cd06-7578-11eb-9344-90324bbf5cee
# 2  36.09  35.45  35.60  36.06  504785de-7578-11eb-96dd-90324bbf5cee
# 3  35.77  34.78  34.78  35.60  50481602-7578-11eb-a671-90324bbf5cee
# 4  35.35  34.21  34.21  35.01  5048c9a8-7578-11eb-8254-90324bbf5cee
#
#              label                name
# 0  inverted_hammer  20200101210000.svg
# 1             doji  20200102210000.svg
# 2     spinning top  20200105210000.svg
# 3           hammer  20200106210000.svg
# 4           hammer  20200107210000.svg

# %% [markdown]
# ### Adding new features

# %%
def create_new_features(df: pd.DataFrame): 
    # the perc can cause inf values. this bias resolves this problem
    bias = 0.00001
    df['diff_hi_low'] = df.high/df.low -1 + bias
    df['diff_close_open'] = df.close/df.open -1 + bias
    df['odds_head_tail_and_body'] = abs(df.diff_hi_low/df.diff_close_open) + bias
    df['diff_high_close_open'] = np.abs(df.high/(np.maximum(df.close, df.open))-1) + bias
    df['diff_low_close_open'] = np.abs(df.low/(np.minimum(df.close, df.open))-1) + bias
    df['odds_head_tail'] = (df.diff_high_close_open/df.diff_low_close_open) + bias
    df['close_grather_open'] = (df.diff_close_open >= 0) * 1
    return df

# %%
df = create_new_features(df)
df
# Out:
#      high    low  close   open                                    id  \
# 0   36.52  35.53  36.52  35.80  5045d02c-7578-11eb-abae-90324bbf5cee
# 1   36.73  35.97  36.14  36.02  5046cd06-7578-11eb-9344-90324bbf5cee
# 2   36.09  35.45  35.60  36.06  504785de-7578-11eb-96dd-90324bbf5cee
# 3   35.77  34.78  34.78  35.60  50481602-7578-11eb-a671-90324bbf5cee
# 4   35.35  34.21  34.21  35.01  5048c9a8-7578-11eb-8254-90324bbf5cee
# ..    ...    ...    ...    ...                                   ...
# 57  21.90  20.87  21.33  21.30  5076d206-7578-11eb-a407-90324bbf5cee
# 58  22.43  21.37  21.39  22.28  507be168-7578-11eb-997f-90324bbf5cee
# 59  24.15  22.48  23.94  22.60  50bae8cc-7578-11eb-a716-90324bbf5cee
# 60  26.03  24.56  24.76  25.96  50c1dcb6-7578-11eb-b593-90324bbf5cee
# 61  30.28  29.53  30.13  30.09  50d2f4ba-7578-11eb-bbf5-90324bbf5cee
#
#               label                name  diff_hi_low  diff_close_open  \
# 0   inverted_hammer  20200101210000.svg     0.027874         0.020122
# 1              doji  20200102210000.svg     0.021139         0.003341
# 2      spinning top  20200105210000.svg     0.018064        -0.012747
# 3            hammer  20200106210000.svg     0.028475        -0.023024
# 4            hammer  20200107210000.svg     0.033334        -0.022841
# ..              ...                 ...          ...              ...
# 57             doji  20200426210000.svg     0.049363         0.001418
# 58         marubozu  20200511210000.svg     0.049612        -0.039936
# 59         marubozu  20201007210000.svg     0.074298         0.059302
# 60         marubozu  20201026210000.svg     0.059863        -0.046215
# 61             doji  20201203210000.svg     0.025408         0.001339
#
#     odds_head_tail_and_body  diff_high_close_open  diff_low_close_open  \
# 0                  1.385267              0.000010             0.007552
# 1                  6.326160              0.016335             0.001398
# 2                  1.417150              0.000842             0.004223
# 3                  1.236763              0.004785             0.000010
# 4                  1.459410              0.009722             0.000010
# ..                      ...                   ...                  ...
# 57                34.800753              0.026733             0.020198
# 58                 1.242299              0.006742             0.000945
# 59                 1.252889              0.008782             0.005320
# 60                 1.295336              0.002706             0.008088
# 61                18.970398              0.004988             0.018621
#
#     odds_head_tail  close_grather_open
# 0         0.001334                   1
# 1        11.683863                   1
# 2         0.199359                   0
# 3       478.528100                   0
# 4       972.151110                   0
# ..             ...                 ...
# 57        1.323567                   1
# 58        7.134802                   0
# 59        1.650831                   1
# 60        0.334655                   0
# 61        0.267905                   1
#
# [62 rows x 14 columns]

# %%
X = df[['diff_hi_low', 'diff_close_open', 'odds_head_tail_and_body', 'diff_high_close_open', 'diff_low_close_open', 'odds_head_tail', 'close_grather_open']]
print(X.shape)
labels = df[['label']]['label'].astype("category")
encoder = LabelBinarizer()
y = encoder.fit_transform(labels)
print(y.shape)
# Out:
# (62, 7)
# (62, 6)

# %%
# 75% train 25% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print(X_train.shape)
print(X_test.shape)
# Out:
# (46, 7)
# (16, 7)

# %%
model = Sequential()
model.add(Dense(500, activation='relu', input_dim=X.shape[1]))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(y.shape[1], activation='softmax'))

# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 15ms/step - loss: 6.1020 - accuracy: 0.1825
# Epoch 2/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.5736 - accuracy: 0.3714
# Epoch 3/100
# 2/2 [==============================] - 0s 6ms/step - loss: 1.3303 - accuracy: 0.5000
# Epoch 4/100
# 2/2 [==============================] - 0s 3ms/step - loss: 1.3081 - accuracy: 0.4792
# Epoch 5/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2201 - accuracy: 0.5208
# Epoch 6/100
# 2/2 [==============================] - 0s 0s/step - loss: 1.1976 - accuracy: 0.5104
# Epoch 7/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1884 - accuracy: 0.4855
# Epoch 8/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1772 - accuracy: 0.5104
# Epoch 9/100
# 2/2 [==============================] - 0s 15ms/step - loss: 1.1362 - accuracy: 0.4896
# Epoch 10/100
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1080 - accuracy: 0.5208
# Epoch 11/100
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0942 - accuracy: 0.5457
# Epoch 12/100
# 2/2 [==============================] - 0s 996us/step - loss: 1.1221 - accuracy: 0.5435
# Epoch 13/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.1469 - accuracy: 0.5122
# Epoch 14/100
# 2/2 [==============================] - 0s 999us/step - loss: 1.0472 - accuracy: 0.5996
# Epoch 15/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0611 - accuracy: 0.5892
# Epoch 16/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0619 - accuracy: 0.5788
# Epoch 17/100
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0582 - accuracy: 0.5788
# Epoch 18/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0051 - accuracy: 0.6245
# Epoch 19/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0208 - accuracy: 0.5996
# Epoch 20/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9930 - accuracy: 0.6037
# Epoch 21/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9755 - accuracy: 0.6245
# Epoch 22/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.0342 - accuracy: 0.5829
# Epoch 23/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9750 - accuracy: 0.6245
# Epoch 24/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9889 - accuracy: 0.5933
# Epoch 25/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.9616 - accuracy: 0.5933
# Epoch 26/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9915 - accuracy: 0.5580
# Epoch 27/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9287 - accuracy: 0.6495
# Epoch 28/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9364 - accuracy: 0.6245
# Epoch 29/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9170 - accuracy: 0.6495
# Epoch 30/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.8831 - accuracy: 0.6639
# Epoch 31/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9065 - accuracy: 0.6431
# Epoch 32/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8821 - accuracy: 0.6390
# Epoch 33/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8762 - accuracy: 0.6680
# Epoch 34/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8721 - accuracy: 0.6889
# Epoch 35/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8675 - accuracy: 0.6784
# Epoch 36/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8779 - accuracy: 0.6472
# Epoch 37/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8138 - accuracy: 0.7138
# Epoch 38/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8392 - accuracy: 0.6390
# Epoch 39/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8170 - accuracy: 0.6286
# Epoch 40/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.8289 - accuracy: 0.6784
# Epoch 41/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7910 - accuracy: 0.7034
# Epoch 42/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7866 - accuracy: 0.6889
# Epoch 43/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7846 - accuracy: 0.6576
# Epoch 44/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7631 - accuracy: 0.6889
# Epoch 45/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7522 - accuracy: 0.7034
# Epoch 46/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7646 - accuracy: 0.7074
# Epoch 47/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7243 - accuracy: 0.7138
# Epoch 48/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7357 - accuracy: 0.6784
# Epoch 49/100
# 2/2 [==============================] - ETA: 0s - loss: 0.6841 - accuracy: 0.71 - 0s 8ms/step - loss: 0.7158 - accuracy: 0.6889
# Epoch 50/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6878 - accuracy: 0.6993
# Epoch 51/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7391 - accuracy: 0.6970
# Epoch 52/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7147 - accuracy: 0.6929
# Epoch 53/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6684 - accuracy: 0.7532
# Epoch 54/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6870 - accuracy: 0.7532
# Epoch 55/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6650 - accuracy: 0.7283
# Epoch 56/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6909 - accuracy: 0.6576
# Epoch 57/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6912 - accuracy: 0.6825
# Epoch 58/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6690 - accuracy: 0.6929
# Epoch 59/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6470 - accuracy: 0.7323
# Epoch 60/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6390 - accuracy: 0.7677
# Epoch 61/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6004 - accuracy: 0.7532
# Epoch 62/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6150 - accuracy: 0.7074
# Epoch 63/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6030 - accuracy: 0.6825
# Epoch 64/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5921 - accuracy: 0.7822
# Epoch 65/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6054 - accuracy: 0.8216
# Epoch 66/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5882 - accuracy: 0.8216
# Epoch 67/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5528 - accuracy: 0.8175
# Epoch 68/100
# 2/2 [==============================] - ETA: 0s - loss: 0.6235 - accuracy: 0.71 - 0s 8ms/step - loss: 0.5894 - accuracy: 0.7468
# Epoch 69/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5509 - accuracy: 0.7781
# Epoch 70/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5482 - accuracy: 0.7926
# Epoch 71/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5547 - accuracy: 0.7572
# Epoch 72/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5630 - accuracy: 0.7572
# Epoch 73/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5486 - accuracy: 0.7468
# Epoch 74/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5293 - accuracy: 0.8216
# Epoch 75/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5356 - accuracy: 0.8007
# Epoch 76/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5182 - accuracy: 0.7717
# Epoch 77/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4955 - accuracy: 0.7926
# Epoch 78/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4896 - accuracy: 0.7926
# Epoch 79/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4875 - accuracy: 0.8175
# Epoch 80/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4953 - accuracy: 0.7717
# Epoch 81/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4947 - accuracy: 0.8610
# Epoch 82/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4505 - accuracy: 0.8569
# Epoch 83/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4743 - accuracy: 0.8111
# Epoch 84/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4668 - accuracy: 0.7966
# Epoch 85/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4654 - accuracy: 0.8071
# Epoch 86/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4356 - accuracy: 0.8673
# Epoch 87/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4549 - accuracy: 0.7862
# Epoch 88/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4311 - accuracy: 0.7781
# Epoch 89/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4420 - accuracy: 0.7966
# Epoch 90/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4262 - accuracy: 0.8610
# Epoch 91/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4094 - accuracy: 0.8465
# Epoch 92/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4113 - accuracy: 0.8216
# Epoch 93/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4062 - accuracy: 0.8279
# Epoch 94/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3924 - accuracy: 0.8465
# Epoch 95/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4023 - accuracy: 0.8610
# Epoch 96/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4047 - accuracy: 0.8859
# Epoch 97/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4187 - accuracy: 0.8755
# Epoch 98/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3820 - accuracy: 0.8610
# Epoch 99/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3722 - accuracy: 0.8859
# Epoch 100/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3754 - accuracy: 0.8175

# %%
train_loss, train_acc = model.evaluate(X_train,  y_train, verbose=2)
# Out:
# 2/2 - 0s - loss: 0.3609 - accuracy: 0.8261

# %%
test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 1.3802 - accuracy: 0.5000

# %% [markdown]
# ### Testing with no labelled data

# %%
test_data = [item['features'] for item in data if len(item['label']) == 0]
test_df = pd.DataFrame(test_data)
test_df.head()
# Out:
#     high    low  close   open                                    id label  \
# 0  33.05  32.35  32.49  32.93  5057b32e-7578-11eb-be72-90324bbf5cee
# 1  32.66  32.06  32.19  32.66  505865e4-7578-11eb-8b82-90324bbf5cee
# 2  32.42  31.68  32.32  32.07  5059170c-7578-11eb-b396-90324bbf5cee
# 3  32.93  32.51  32.67  32.89  505a885c-7578-11eb-af82-90324bbf5cee
# 4  31.69  30.43  31.61  30.72  505d4fd4-7578-11eb-8bbe-90324bbf5cee
#
#                  name
# 0  20200213210000.svg
# 1  20200216210000.svg
# 2  20200217210000.svg
# 3  20200219210000.svg
# 4  20200227210000.svg

# %%
test_df = create_new_features(test_df)
test_df
# Out:
#       high    low  close   open                                    id label  \
# 0    33.05  32.35  32.49  32.93  5057b32e-7578-11eb-be72-90324bbf5cee
# 1    32.66  32.06  32.19  32.66  505865e4-7578-11eb-8b82-90324bbf5cee
# 2    32.42  31.68  32.32  32.07  5059170c-7578-11eb-b396-90324bbf5cee
# 3    32.93  32.51  32.67  32.89  505a885c-7578-11eb-af82-90324bbf5cee
# 4    31.69  30.43  31.61  30.72  505d4fd4-7578-11eb-8bbe-90324bbf5cee
# ..     ...    ...    ...    ...                                   ...   ...
# 166  29.65  28.76  28.82  28.91  50cf2f54-7578-11eb-8ecc-90324bbf5cee
# 167  29.06  28.43  28.43  28.83  50cfe39c-7578-11eb-902c-90324bbf5cee
# 168  30.34  28.82  29.63  28.93  50d0858c-7578-11eb-8b71-90324bbf5cee
# 169  30.11  29.32  29.85  29.79  50d14636-7578-11eb-a630-90324bbf5cee
# 170  30.75  29.77  29.83  30.01  50d2308c-7578-11eb-9a0e-90324bbf5cee
#
#                    name  diff_hi_low  diff_close_open  \
# 0    20200213210000.svg     0.021648        -0.013352
# 1    20200216210000.svg     0.018725        -0.014381
# 2    20200217210000.svg     0.023369         0.007805
# 3    20200219210000.svg     0.012929        -0.006679
# 4    20200227210000.svg     0.041417         0.028981
# ..                  ...          ...              ...
# 166  20201126210000.svg     0.030956        -0.003103
# 167  20201129210000.svg     0.022170        -0.013864
# 168  20201130210000.svg     0.052751         0.024206
# 169  20201201210000.svg     0.026954         0.002024
# 170  20201202210000.svg     0.032929        -0.005988
#
#      odds_head_tail_and_body  diff_high_close_open  diff_low_close_open  \
# 0                   1.621404              0.003654             0.004319
# 1                   1.302097              0.000010             0.004049
# 2                   2.993892              0.003104             0.012171
# 3                   1.935805              0.001226             0.004907
# 4                   1.429084              0.002541             0.009450
# ..                       ...                   ...                  ...
# 166                 9.975732              0.025607             0.002092
# 167                 1.599043              0.007988             0.000010
# 168                 2.179239              0.023972             0.003812
# 169                13.316587              0.008720             0.015787
# 170                 5.499182              0.024668             0.002021
#
#      odds_head_tail  close_grather_open
# 0          0.846057                   0
# 1          0.002480                   0
# 2          0.255049                   1
# 3          0.249869                   0
# 4          0.268879                   1
# ..              ...                 ...
# 166       12.240954                   0
# 167      798.780100                   0
# 168        6.288161                   1
# 169        0.552373                   1
# 170       12.203667                   0
#
# [171 rows x 14 columns]

# %%
X = test_df[['diff_hi_low', 'diff_close_open', 'odds_head_tail_and_body', 'diff_high_close_open', 'diff_low_close_open', 'odds_head_tail', 'close_grather_open']]
X.head()
# Out:
#    diff_hi_low  diff_close_open  odds_head_tail_and_body  \
# 0     0.021648        -0.013352                 1.621404
# 1     0.018725        -0.014381                 1.302097
# 2     0.023369         0.007805                 2.993892
# 3     0.012929        -0.006679                 1.935805
# 4     0.041417         0.028981                 1.429084
#
#    diff_high_close_open  diff_low_close_open  odds_head_tail  \
# 0              0.003654             0.004319        0.846057
# 1              0.000010             0.004049        0.002480
# 2              0.003104             0.012171        0.255049
# 3              0.001226             0.004907        0.249869
# 4              0.002541             0.009450        0.268879
#
#    close_grather_open
# 0                   0
# 1                   0
# 2                   1
# 3                   0
# 4                   1

# %%
predictions = model.predict(X)
predictions
# Out:
# array([[3.1481083e-02, 3.1529278e-02, 6.9711413e-03, 2.4228373e-01,
#         2.4528287e-01, 4.4245186e-01],
#        [4.0320102e-02, 3.7693892e-02, 6.0834453e-02, 3.6747751e-01,
#         3.8212687e-01, 1.1154714e-01],
#        [5.1587403e-01, 1.0395654e-03, 5.0206427e-03, 2.3672396e-02,
#         9.9547049e-03, 4.4443870e-01],
#        ...,
#        [5.1901340e-03, 8.7505502e-01, 4.6184000e-06, 2.2220197e-03,
#         9.4338357e-02, 2.3189887e-02],
#        [9.8610967e-01, 2.4530791e-14, 1.1235914e-02, 3.0371993e-08,
#         1.3082431e-15, 2.6544235e-03],
#        [8.0748624e-01, 2.4461636e-02, 1.0908263e-06, 7.3573238e-04,
#         8.9449680e-04, 1.6642083e-01]], dtype=float32)

# %%
predictions.shape
# Out:
# (171, 6)

# %%
classes = encoder.classes_

for idx, pred in enumerate(predictions):
    test_df.iloc[idx, test_df.columns.get_loc('label')] = classes[np.argmax(pred)]

test_df.head()
# Out:
#     high    low  close   open                                    id  \
# 0  33.05  32.35  32.49  32.93  5057b32e-7578-11eb-be72-90324bbf5cee
# 1  32.66  32.06  32.19  32.66  505865e4-7578-11eb-8b82-90324bbf5cee
# 2  32.42  31.68  32.32  32.07  5059170c-7578-11eb-b396-90324bbf5cee
# 3  32.93  32.51  32.67  32.89  505a885c-7578-11eb-af82-90324bbf5cee
# 4  31.69  30.43  31.61  30.72  505d4fd4-7578-11eb-8bbe-90324bbf5cee
#
#           label                name  diff_hi_low  diff_close_open  \
# 0  spinning top  20200213210000.svg     0.021648        -0.013352
# 1      marubozu  20200216210000.svg     0.018725        -0.014381
# 2          doji  20200217210000.svg     0.023369         0.007805
# 3  spinning top  20200219210000.svg     0.012929        -0.006679
# 4      marubozu  20200227210000.svg     0.041417         0.028981
#
#    odds_head_tail_and_body  diff_high_close_open  diff_low_close_open  \
# 0                 1.621404              0.003654             0.004319
# 1                 1.302097              0.000010             0.004049
# 2                 2.993892              0.003104             0.012171
# 3                 1.935805              0.001226             0.004907
# 4                 1.429084              0.002541             0.009450
#
#    odds_head_tail  close_grather_open
# 0        0.846057                   0
# 1        0.002480                   0
# 2        0.255049                   1
# 3        0.249869                   0
# 4        0.268879                   1

# %% [markdown]
# ### Show results

# %%
from IPython.display import SVG, display
def show_svg(filename):
    display(SVG(filename=f'../classifier/static/classify_data/{filename}'))

# %%
for i in range(10):
    name = test_df.iloc[i].name
    label = test_df.iloc[i].label
    show_svg(f'{name}.svg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-f0ab79e0ede3> in <module>
#       2     name = test_df.iloc[i].name
#       3     label = test_df.iloc[i].label
# ----> 4     show_svg(f'{name}.svg')
#
# <ipython-input-26-93fbb6a9f586> in show_svg(filename)
#       1 from IPython.display import SVG, display
#       2 def show_svg(filename):
# ----> 3     display(SVG(filename=f'../classifier/static/classify_data/{filename}'))
#
# c:\users\tenta\.conda\envs\image_classifier\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, metadata)
#     628             self.metadata = {}
#     629
# --> 630         self.reload()
#     631         self._check_data()
#     632
#
# c:\users\tenta\.conda\envs\image_classifier\lib\site-packages\IPython\core\display.py in reload(self)
#     653         """Reload the raw data from file or URL."""
#     654         if self.filename is not None:
# --> 655             with open(self.filename, self._read_flags) as f:
#     656                 self.data = f.read()
#     657         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../classifier/static/classify_data/0.svg'
